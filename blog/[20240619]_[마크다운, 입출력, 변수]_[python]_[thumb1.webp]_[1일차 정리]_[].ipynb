# %% [markdown]
# # 오늘의 상식
#
# slop: 쓰레기, 오물을 뜻하는데 생성형 AI로 인해 수많은 정제되지 못한 창작물들을 말하는 용어
#
# Django로 만들어진 서비스: 유튜브, 인스타그램, 당근(사용만), 요기요, 뱅크샐러드, 쿠팡(일부)
#
# <무엇을 만들 것인가> -> 좋은 비지니스 모델, 스타트업 창업 전략 복습하기
#
# 파이썬 최신 소식
# https://planetpython.org/?fbclid=IwZXh0bgNhZW0CMTEAAR0bSwcA-NlptDe0_4kanikErlA8G5JPh0jlM67WElYHA-HuijLrGyUlT08_aem_AYU5YV-VRP3ccADUFJJQUrwpreJXJ-Q3JwN3UmwLLYYxqARRsCG64RJrYyDrgQUSeVw7imxAWrXusMTfHSCIHl6I
#
# 릴리스 AI: 유튜브 요약 및 스크립트
#
# 유로 생성형 AI 쓸 수 있는 웹 페이지 https://chat.lmsys.org/

# %% [markdown]
# # 생성 방법
#
# Shift + Enter 실행 후 다음 칸으로 이동
#
# Ctrl + Enter 실행
#
# Alt + Enter 실행 후 생성
#
# Ctrl M A : 코드 셀 위에 삽입
#
# Ctrl M B : 코드 셀 아래 삽입
#
# Ctrl M D : 셀 지우기
#
# Ctrl M Y : 코드 셀로 변경
#
# Ctrl M M ; 마크다운 셀로 이동
#
# Ctrl M Z : 실행 취소

# %% [markdown]
# # 수정 단축 키
# `Ctrl(Command)` + `Alt(Option)` + 화살표위아래 : 동시 수정
#
# - 자주 쓰는 예시 필요
#
# (자주) `Ctrl(Command)` + D : 같은 단어 찾아 동시 수정
#
# `Ctrl(Command)` + `Shift` + L : 동일 단어를 전체로 찾아 동시 수정
#
# `Alt(Option)` + `Shift` + 화살표위아래 : 해당내용을 위나 아래 복사해서 붙여넣기
#
# `Alt(Option)` + 화살표위아래 : 해당 내용을 위나 아래로 보내기
#
# (자주) `Ctrl(Command)` + `Alt(Option)` + 화살표위아래 : 위아래 동시 수정
#
# (자주) Home, End : 문장의 양 끝
#
# (필수) `Ctrl(Command)` + `/` : 주석
#
# (필수) `Shift`(`Command`) + `Del` : 한 줄 지우기
#
# (필수) `Tab`, `Ctrl` + `]` : 들여쓰기
#
# (필수) `Shift` + `Tab`, `Ctrl` + `[` : 내어쓰기

# %% [markdown]
# # 마크다운
# ## 헤더1
# ### 헤더2
# #### 헤더3
# ##### 헤더4
# ###### 헤더5
#
# /#의 개수는 제목의 수준을 뜻함
#
# 정의: 쉽게 작성 가능, HTML 변환 가능
#
# 목적: 앱 컨텐츠 작성
#
# 가독성, 편의성, 표준화

# %% [markdown]
# ## 강조
#
# 1. *
# 2. _
#
# *강조*
#
# **강조**
#
# _강조_

# %% [markdown]
# ## 목록
#
# ### 순서 있는 목록
#
# 1. 첫번째 목록
# 2. 두번째 목록
#
# ### 순서 없는 목록
#
# * 순서없는 목록1
# * 순서없는 목록2
# * 순서없는 목록3

# %% [markdown]
# ## 링크
#
# - **사용법**: \[텍스트](URL) 형식을 사용하여 하이퍼링크 삽입

# %% [markdown]
# ## 이미지
#
# - **사용법**:  !\[텍스트](URL)!형식을 사용하여 하이퍼링크 삽입

# %% [markdown]
# ## 코드
#
# > 인용문
# >> 중첩된 인용
#
# ---
# 구분선
# ---
#
# ~~취소선~~

# %% [markdown]
# # 개발 프로세스
#
# ## 문제 정의하기
#
# 섹션 1: 문제 이해
#
# 핵심 포인트
#
# - 문제의 배경과 목적 이해
# - 문제의 핵심 파악
# - 실생활과의 연관성 인식
#
# 섹션 2: 요구사항 분석
#
# - 입력과 출력의 이해
# - 문제 해결을 위한 필수 정보 식별
#
# ## 계획 수립하기
#
# - 알고리즘
# - 문제수정
# - 최적화, 리펙토링
# - 문서화
# - 유지보수

# %% [markdown]
# # 파이썬으로 할 수 있는 것
#
# 1. 웹 서비스 개발
# 2. 데이터 분석
# 3. 머신러닝(인공지능)
# 4. 업무 자동화
#     - 보고서, 문서발송
#     - 단순 반복 업무
#     - 영상 편집 업무
#     - 노션 자동 완성
# 5. 웹 스크레이핑
# 6. 하드웨어 제어
# 7. 데스크톱 어플 개발

# %% [markdown]
# # 주석
#
# ## 1.1 주석이란?
#
# 목적 설명을 위한 안내
#
# ## 1.2 주석 생성
# 코드 주석
#
# \#: 한 줄 주석
#
# ''' 여러줄 주석 '''
#
# ## 파이썬 코드 스타일 가이드
#
# '[파이썬 코드 스타일 가이드](https://google.github.io/styleguide/pyguide.html)'

# %% [markdown]
# # 입력과 출력

# %% [markdown]
# ## 입력함수 input

# %%
age = input('나이를 입력해주세요: ')
print(age + age)

# 1. input을 출력하면 결과창에 입력하는 화면이 나온다.
# 2. 입력된 값이 age라는 변수에 저장된다.
# 3. 변수는 계산이 된다.
# 4. 변수의 type 생각하기
# Out:
# 나이를 입력해주세요: 12
# 1212

# %%
age = int(input('나이를 입력해주세요: '))
print(age+age)

# 숫자형 Type: int, float 등
# 문자열 Type: str
# Out:
# 나이를 입력해주세요: 23
# 46

# %% [markdown]
# ## 출력함수 print

# %%
print('Hello World')
# Out:
# Hello World

# %%
'Hello' + 'World'

# ''로만 써서 디버깅 시 활용
# Out:
# 'HelloWorld'

# %%
print('010', '1234', '5678', sep='-', end = '???')
# sep: 문자열 사이에 삽입
# end: 문자열 끝에 삽입
# Out:
# 010-1234-5678???

# %% [markdown]
# ## f-string

# %%
name = input('이름을 입력해주세요: ')
age = int(input('나이를 입력해주세요: '))
print(f"Hello World! nice to meet you, {name}, {name} is {age} years old")

# 변수를 추가할 때 가독성이 좋음
# Out:
# 이름을 입력해주세요: kevin
# 나이를 입력해주세요: 12
# Hello World! nice to meet you, kevin, kevin is 12 years old

# %%
# None은 마지막 라인에 출력되지 않는다.
# print문을 사용하지 않으면 출력 X

a = None
a

# %% [markdown]
# # 타입

# %% [markdown]
# ## 변수

# %% [markdown]
# ### 1. 변수 생성

# %%
age = 30
name = '김민수' # 문자열을 사용할 때는 꼭 따옴표나 쌍따옴
print(age, name)
# Out:
# 30 김민수

# %%
x = 10
y = x
z = y

print(z)
# Out:
# 10

# %%
x = 10
y = x
z = y
x = 20   # 변수를 재할당했을 때, 연결되었다 하더라도 다른 변수 값은 변하지 않음.

print(x, y, z)
# Out:
# 20 10 10

# %% [markdown]
# ### 2. 변수의 이름 짓기
#
# - 변수 이름은 알파벳, 숫자, 언더스코어(_)로 구성
# - 변수 이름은 숫자로 시작할 수 없음
# - 파이썬의 키워드(if, else, try 등)는 변수로 사용할 수 없음
# - 하이픈은 허용되지 않음
# - 변수 이름은 대소문자를 구분함
# - 변수명이 같으면 덮어쓰기처럼 작용한다.
# - 일반변수는 첫 문자를 소문자로 사용함, Class만 첫 문자가 대문자
# - 사용하지 않는 변수는 언더스코어(_)로 명명
# - 스네이크 표기법(ex. daily_user_count)

# %% [markdown]
# ### 3. 변수의 타입
#
# 타입은 변수를 어떻게 관리하고 처리할 것인지 결정

# %%
age = 30
print(type(age))

name = '김민수'
print(type(name))
# Out:
# <class 'int'>
# <class 'str'>

# %%
print(dir(age))  # dir: 가능한 class 종류를 보여줌
# Out:
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_count', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']

# %%
x = 1
y = x

print(x, y)
del x  # 변수 삭제, 삭제를 할 때는 신중하게 할 것
print(y)
# Out:
# 1 1
# 1

# %% [markdown]
# ### 정수(int)자료형

# %%
# 인티저(integer)

print(type(10))

x = 10
x2 = 10.0

print(x == x2)
# Out:
# <class 'int'>
# True

# %%
# 정수의 사칙연산

x = 10
y = 3

result = x + y  # 결과가 정수형
print(result)
result = x - y  # 결과가 정수형
print(result)
result = x * y  # 결과가 정수형
print(result)
result = x / y  # 결과가 실수형
print(result)

'''
머신러닝에서 최적화 과정에서 나눗셈이 많이 적용되고
소수점에 따라 달라짐.
'''
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# '\n머신러닝에서 최적화 과정에서 나눗셈이 많이 적용되고\n소수점에 따라 달라짐.\n'

# %%
x = 10
y = 3

result = x // y  # 몫
print(result)
result = x % y  # 나머지
print(result)
# Out:
# 3
# 1

# %%
# 진수
# b: 2진수,o: 8진수, x: 16진수(색깔 표현 시 사용)
x = 731
y = 0b0110  # 2진수
z = 0o123  # 8진수
w = 0x123  # 16진수

print(x, y, z, w)
# Out:
# 731 6 83 291

# %%
# 메서드

x = 'hello'
print(x.upper())
print(x.lower())
print(x.capitalize())
print(x.title())
# Out:
# HELLO
# hello
# Hello
# Hello

# %%
# id
'''
 -5 ~ 256은 메모리에 똑같이 할당되지만,
그 외 나머지는 같은 값이더라도 id가 다를 수 있음
'''

x = 5453
print(id(x)) # 출력값: 134179368864560

y = 5453
print(id(y)) # 출력값: 134179368863504

# 다른 메모리에 재할당돼서 값이 바뀔 수 있음
# Out:
# 134179368865168
# 134179368864336

# %% [markdown]
# ### 실수(float)자료형

# %%
x = 10.0
y = 3.0

result = x + y  # 결과가 실수형
print(result)

# 금융 어플의 경우 -> 10000.00 -> 10000원 형태의 중요성(UI/UX)
# Out:
# 13.0

# %%
# float의 특수 값

x = float('inf')
y = float('-inf')
z = float('nan') # 계산 오류

print(x > 10)
print(y > 10)
print(z == 10)

# 부동소수점 문제
# Out:
# True
# False
# False

# %%
# 승수 e

x = 10e5
y = 10e-5

print(x)  # 1000000.0
print(y)  # 0.00001
# Out:
# 1000000.0
# 0.0001

# %% [markdown]
# ### 문자열(str)자료형
#
# 문자'열' -> 순서, 규칙 존재

# %%
# 짧은 문장

x = 'Hello'
y = "World"

print(x, y)
print(f'{x} {y}')
print(type(x), type(y))
# Out:
# Hello World
# Hello World
# <class 'str'> <class 'str'>

# %%
# 긴 문장

x = '''
Hello
World
'''

print(x)
# Out:
# Hello
# World

# %% [markdown]
# #### 문자열의 특징

# %%
# 문자의 합과 곱

x = 'Hello'
y = "World"

print(x + y)
print(x * 3)
# Out:
# HelloWorld
# HelloHelloHello

# %% [markdown]
# #### 문자열 인덱싱

# %%
x = '위니브 월드'
#    0 1 2 3 4 5
#    -6-5-4-3-2-1

print(x[0])  # 첫번째 문자
print(x[-1])  # 마지막 문자
print(x[0:2])  # 0부터 1까지, 0 <= x < 2, 2(stop) 포함 안됨
print(x[2:])  # 2부터 끝
print(x[:2])    # 처음부터 1
print(x[::-1])  # 역순
print(x[::2])  # 짝수
print(x[1::2])  # 홀수

# x[start:stop:step], : = 슬라이싱(리스트 일부 선택), 기본 스텝: 1
# Out:
# 위
# 드
# 위니
# 브 월드
# 위니
# 드월 브니위
# 위브월
# 니 드

# %%
s = 'weniv_licat.png'

# .png 삭제

print(s[:-4])  # weniv_licat
# Out:
# weniv_licat

# %%
s = 'weniv_licat.png'

# .png 표시

print(s[-4:])  # .png

'''
슬라이싱이 메서드보다 더 처리 속도가 빠름.
따라서, 메서드로 자르기 보단 슬라이싱으로 자르는 것이 바람직함
'''
# Out:
# .png
